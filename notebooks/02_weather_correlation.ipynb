# %% [markdown]
# # 02 — Weather Correlation Analysis
#
# Pearson correlation between PM2.5 and weather variables.

# %%
import duckdb
from pathlib import Path

conn = duckdb.connect(str(Path('../data/warehouse/kyiv.duckdb')))
conn.sql('SELECT * FROM mart_weather_correlation').show()
